# %%
# %pip install ultralytics opencv-python filterpy pillow
# %pip install pyqt5
# Out:
# Collecting ultralyticsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading ultralytics-8.3.139-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in c:\users\ranja\anaconda3\lib\site-packages (4.11.0.86)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pillow in c:\users\ranja\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.7.0-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.22.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\ranja\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ranja\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ranja\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ranja\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ranja\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ranja\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ranja\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ranja\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\ranja\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\ranja\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ranja\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ranja\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ranja\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Downloading ultralytics-8.3.139-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 837.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.2 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp312-cp312-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/212.5 MB ? eta -:--:--
#    ---------------------------------------- 0.8/212.5 MB 1.9 MB/s eta 0:01:54
#    ---------------------------------------- 1.3/212.5 MB 2.2 MB/s eta 0:01:35
#    ---------------------------------------- 2.1/212.5 MB 2.7 MB/s eta 0:01:18
#     --------------------------------------- 3.1/212.5 MB 3.1 MB/s eta 0:01:09
#     --------------------------------------- 3.9/212.5 MB 3.3 MB/s eta 0:01:04
#     --------------------------------------- 4.5/212.5 MB 3.2 MB/s eta 0:01:06
#     --------------------------------------- 5.2/212.5 MB 3.2 MB/s eta 0:01:05
#    - -------------------------------------- 6.0/212.5 MB 3.3 MB/s eta 0:01:04
#    - -------------------------------------- 7.1/212.5 MB 3.4 MB/s eta 0:01:01
#    - -------------------------------------- 7.9/212.5 MB 3.5 MB/s eta 0:00:59
#    - -------------------------------------- 8.4/212.5 MB 3.6 MB/s eta 0:00:58
#    - -------------------------------------- 9.4/212.5 MB 3.5 MB/s eta 0:00:58
#    -- ------------------------------------- 10.7/212.5 MB 3.7 MB/s eta 0:00:55
#    -- ------------------------------------- 11.8/212.5 MB 3.8 MB/s eta 0:00:53
#    -- ------------------------------------- 12.8/212.5 MB 3.9 MB/s eta 0:00:52
#    -- ------------------------------------- 13.6/212.5 MB 3.9 MB/s eta 0:00:52
#    -- ------------------------------------- 14.4/212.5 MB 3.9 MB/s eta 0:00:51
#    -- ------------------------------------- 15.2/212.5 MB 3.9 MB/s eta 0:00:51
#    -- ------------------------------------- 15.7/212.5 MB 3.9 MB/s eta 0:00:51
#    -- ------------------------------------- 15.7/212.5 MB 3.9 MB/s eta 0:00:51
#    --- ------------------------------------ 17.8/212.5 MB 3.9 MB/s eta 0:00:50
#    --- ------------------------------------ 19.1/212.5 MB 4.0 MB/s eta 0:00:49
#    --- ------------------------------------ 20.2/212.5 MB 4.1 MB/s eta 0:00:48
#    --- ------------------------------------ 20.7/212.5 MB 4.0 MB/s eta 0:00:48
#    --- ------------------------------------ 21.2/212.5 MB 4.0 MB/s eta 0:00:48
#    ---- ----------------------------------- 22.3/212.5 MB 4.0 MB/s eta 0:00:48
#    ---- ----------------------------------- 23.1/212.5 MB 4.0 MB/s eta 0:00:48
#    ---- ----------------------------------- 24.4/212.5 MB 4.1 MB/s eta 0:00:47
#    ---- ----------------------------------- 25.7/212.5 MB 4.1 MB/s eta 0:00:46
#    ----- ---------------------------------- 26.7/212.5 MB 4.2 MB/s eta 0:00:45
#    ----- ---------------------------------- 28.0/212.5 MB 4.2 MB/s eta 0:00:44
#    ----- ---------------------------------- 29.4/212.5 MB 4.3 MB/s eta 0:00:43
#    ----- ---------------------------------- 30.7/212.5 MB 4.4 MB/s eta 0:00:42
#    ----- ---------------------------------- 31.7/212.5 MB 4.4 MB/s eta 0:00:42
#    ------ --------------------------------- 33.0/212.5 MB 4.5 MB/s eta 0:00:41
#    ------ --------------------------------- 34.3/212.5 MB 4.5 MB/s eta 0:00:40
#    ------ --------------------------------- 35.7/212.5 MB 4.5 MB/s eta 0:00:39
#    ------ --------------------------------- 37.0/212.5 MB 4.6 MB/s eta 0:00:39
#    ------- -------------------------------- 38.3/212.5 MB 4.6 MB/s eta 0:00:38
#    ------- -------------------------------- 39.6/212.5 MB 4.7 MB/s eta 0:00:38
#    ------- -------------------------------- 40.6/212.5 MB 4.7 MB/s eta 0:00:37
#    ------- -------------------------------- 42.2/212.5 MB 4.7 MB/s eta 0:00:36
#    -------- ------------------------------- 43.5/212.5 MB 4.8 MB/s eta 0:00:36
#    -------- ------------------------------- 44.8/212.5 MB 4.8 MB/s eta 0:00:35
#    -------- ------------------------------- 46.1/212.5 MB 4.8 MB/s eta 0:00:35
#    -------- ------------------------------- 47.4/212.5 MB 4.9 MB/s eta 0:00:34
#    --------- ------------------------------ 48.5/212.5 MB 4.9 MB/s eta 0:00:34
#    --------- ------------------------------ 50.1/212.5 MB 4.9 MB/s eta 0:00:33
#    --------- ------------------------------ 51.4/212.5 MB 4.9 MB/s eta 0:00:33
#    --------- ------------------------------ 52.7/212.5 MB 5.0 MB/s eta 0:00:33
#    ---------- ----------------------------- 54.0/212.5 MB 5.0 MB/s eta 0:00:32
#    ---------- ----------------------------- 55.3/212.5 MB 5.0 MB/s eta 0:00:32
#    ---------- ----------------------------- 56.6/212.5 MB 5.0 MB/s eta 0:00:31
#    ---------- ----------------------------- 57.7/212.5 MB 5.1 MB/s eta 0:00:31
#    ----------- ---------------------------- 59.2/212.5 MB 5.1 MB/s eta 0:00:31
#    ----------- ---------------------------- 60.3/212.5 MB 5.1 MB/s eta 0:00:30
#    ----------- ---------------------------- 61.6/212.5 MB 5.1 MB/s eta 0:00:30
#    ----------- ---------------------------- 62.9/212.5 MB 5.1 MB/s eta 0:00:30
#    ------------ --------------------------- 64.2/212.5 MB 5.2 MB/s eta 0:00:29
#    ------------ --------------------------- 65.5/212.5 MB 5.2 MB/s eta 0:00:29
#    ------------ --------------------------- 66.8/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------ --------------------------- 68.2/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 69.5/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 70.5/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.8/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 73.1/212.5 MB 5.3 MB/s eta 0:00:27
#    -------------- ------------------------- 74.4/212.5 MB 5.3 MB/s eta 0:00:27
#    -------------- ------------------------- 76.0/212.5 MB 5.3 MB/s eta 0:00:26
#    -------------- ------------------------- 77.1/212.5 MB 5.3 MB/s eta 0:00:26
#    -------------- ------------------------- 78.4/212.5 MB 5.3 MB/s eta 0:00:26
#    --------------- ------------------------ 80.0/212.5 MB 5.4 MB/s eta 0:00:25
#    --------------- ------------------------ 81.0/212.5 MB 5.3 MB/s eta 0:00:25
#    --------------- ------------------------ 82.3/212.5 MB 5.4 MB/s eta 0:00:25
#    --------------- ------------------------ 83.9/212.5 MB 5.4 MB/s eta 0:00:24
#    ---------------- ----------------------- 85.2/212.5 MB 5.4 MB/s eta 0:00:24
#    ---------------- ----------------------- 86.5/212.5 MB 5.4 MB/s eta 0:00:24
#    ---------------- ----------------------- 87.8/212.5 MB 5.4 MB/s eta 0:00:23
#    ---------------- ----------------------- 89.4/212.5 MB 5.4 MB/s eta 0:00:23
#    ----------------- ---------------------- 90.4/212.5 MB 5.4 MB/s eta 0:00:23
#    ----------------- ---------------------- 91.8/212.5 MB 5.5 MB/s eta 0:00:23
#    ----------------- ---------------------- 93.1/212.5 MB 5.5 MB/s eta 0:00:22
#    ----------------- ---------------------- 94.4/212.5 MB 5.5 MB/s eta 0:00:22
#    ------------------ --------------------- 95.7/212.5 MB 5.5 MB/s eta 0:00:22
#    ------------------ --------------------- 97.0/212.5 MB 5.5 MB/s eta 0:00:22
#    ------------------ --------------------- 98.3/212.5 MB 5.5 MB/s eta 0:00:21
#    ------------------ --------------------- 99.6/212.5 MB 5.5 MB/s eta 0:00:21
#    ------------------- -------------------- 101.2/212.5 MB 5.5 MB/s eta 0:00:21
#    ------------------- -------------------- 102.2/212.5 MB 5.5 MB/s eta 0:00:20
#    ------------------- -------------------- 103.5/212.5 MB 5.5 MB/s eta 0:00:20
#    ------------------- -------------------- 104.9/212.5 MB 5.6 MB/s eta 0:00:20
#    ------------------- -------------------- 106.2/212.5 MB 5.6 MB/s eta 0:00:20
0 MB/s eta 0:00:04
#    ----------------------------------- ---- 190.1/212.5 MB 6.1 MB/s eta 0:00:04
#    ------------------------------------ --- 191.4/212.5 MB 6.1 MB/s eta 0:00:04
#    ------------------------------------ --- 192.7/212.5 MB 6.1 MB/s eta 0:00:04
#    ------------------------------------ --- 194.0/212.5 MB 6.1 MB/s eta 0:00:04
#    ------------------------------------ --- 195.3/212.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------------------- -- 196.6/212.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------------------- -- 198.2/212.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------------------- -- 199.2/212.5 MB 6.1 MB/s eta 0:00:03
#    ------------------------------------- -- 200.5/212.5 MB 6.2 MB/s eta 0:00:02
#    ------------------------------------- -- 201.6/212.5 MB 6.1 MB/s eta 0:00:02
#    -------------------------------------- - 202.9/212.5 MB 6.1 MB/s eta 0:00:02
#    -------------------------------------- - 203.9/212.5 MB 6.1 MB/s eta 0:00:02
#    -------------------------------------- - 205.3/212.5 MB 6.2 MB/s eta 0:00:02
#    -------------------------------------- - 206.6/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  207.6/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  208.9/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  210.2/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  211.6/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 212.5/212.5 MB 6.1 MB/s eta 0:00:00
# Downloading torchvision-0.22.0-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.6/6.3 MB 6.3 MB/s eta 0:00:01
#    ------------------------ --------------- 3.9/6.3 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 6.2 MB/s eta 0:00:00
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py): started
#   Building wheel for filterpy (setup.py): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110541 sha256=f78ec6018b277d4cb8c2fab52d84c2df16816fe168ebfa597a3a6665f18a6f55
#   Stored in directory: c:\users\ranja\appdata\local\pip\cache\wheels\77\bf\4c\b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# Installing collected packages: sympy, torch, ultralytics-thop, torchvision, filterpy, ultralytics
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed filterpy-1.4.5 sympy-1.14.0 torch-2.7.0 torchvision-0.22.0 ultralytics-8.3.139 ultralytics-thop-2.0.14
# Requirement already satisfied: pyqt5 in c:\users\ranja\anaconda3\lib\site-packages (5.15.10)
# Requirement already satisfied: PyQt5-sip<13,>=12.13 in c:\users\ranja\anaconda3\lib\site-packages (from pyqt5) (12.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import threading
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from tkinter import *
from PIL import Image, ImageTk

# Load YOLOv8 model
model = YOLO('yolov8n.pt')
tracker = DeepSort(max_age=30)

# GUI setup
class ObjectDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("YOLOv8 + DeepSORT Object Tracker")

        # GUI Components
        self.video_label = Label(root)
        self.video_label.pack()

        self.start_button = Button(root, text="Start Tracking", command=self.start_tracking)
        self.start_button.pack(pady=10)

        self.stop_button = Button(root, text="Stop", command=self.stop_tracking, state=DISABLED)
        self.stop_button.pack()

        self.cap = None
        self.running = False

    def start_tracking(self):
        self.running = True
        self.start_button.config(state=DISABLED)
        self.stop_button.config(state=NORMAL)
        self.cap = cv2.VideoCapture(0)  # webcam
        threading.Thread(target=self.update_frame).start()

    def stop_tracking(self):
        self.running = False
        self.start_button.config(state=NORMAL)
        self.stop_button.config(state=DISABLED)
        if self.cap:
            self.cap.release()

    def update_frame(self):
        while self.running:
            ret, frame = self.cap.read()
            if not ret:
                break

            resized_frame = cv2.resize(frame, (640, 480))
            results = model(resized_frame)[0]
            detections = []

            for result in results.boxes:
                x1, y1, x2, y2 = map(int, result.xyxy[0].tolist())
                conf = float(result.conf[0])
                cls = int(result.cls[0])
                detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls))

            tracks = tracker.update_tracks(detections, frame=resized_frame)

            for track in tracks:
                if not track.is_confirmed():
                    continue
                track_id = track.track_id
                ltrb = track.to_ltrb()
                x1, y1, x2, y2 = map(int, ltrb)
                cv2.rectangle(resized_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(resized_frame, f'ID: {track_id}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

            # Convert frame to display in Tkinter
            image = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2RGB)
            img = Image.fromarray(image)
            imgtk = ImageTk.PhotoImage(image=img)

            self.video_label.imgtk = imgtk
            self.video_label.configure(image=imgtk)

        if self.cap:
            self.cap.release()

# Run the GUI
if __name__ == "__main__":
    root = Tk()
    app = ObjectDetectionApp(root)
    root.mainloop()
# Out:
# 0: 480x640 2 persons, 1 dog, 213.2ms
# Speed: 5.3ms preprocess, 213.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.2ms
# Speed: 4.9ms preprocess, 175.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
